# %% [markdown]
# # Python Fundamentals Summary
# Small examples used to establish reusable project patterns.

# %%
# --- run me first ---
from pathlib import Path
import os, sys
if Path.cwd().name == "notebooks":
    os.chdir("..")
ROOT = Path.cwd()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
print("working from:", ROOT.name)
# Out:
# working from: project

# %%
import numpy as np, pandas as pd
arr = np.array([1,2,3,4])
print("vectorized:", arr * 2)
demo = pd.DataFrame({"date":["2025-01-31","2025-02-28"],"value":[1.0,2.0]})
demo
# Out:
# vectorized: [2 4 6 8]
#          date  value
# 0  2025-01-31    1.0
# 1  2025-02-28    2.0

# %%
from src.utils import parse_date_column, missing_summary
demo = parse_date_column(demo)
print(demo.dtypes)
missing_summary(demo)
# Out:
# date     datetime64[ns]
# value           float64
# dtype: object
# date     0
# value    0
# dtype: int64
