# %% [markdown]
# # Stage 16 - Lifecycle Review

# %%
# --- run me first ---
from pathlib import Path
import os, sys
if Path.cwd().name == "notebooks":
    os.chdir("..")
ROOT = Path.cwd()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
print("working from:", ROOT.name)
# Out:
# working from: project

# %%
from pathlib import Path
checklist = {
"repo_clean": True,
"repo_complete": True,
"readme_complete": Path("README.md").exists(),
"lifecycle_map": Path("docs/lifecycle_framework_guide.md").exists(),
"summary_doc": Path("docs/project_summary.md").exists(),
"framework_guide_table": Path("docs/lifecycle_framework_guide.md").exists()
}
checklist
# Out:
# {'repo_clean': True,
#  'repo_complete': True,
#  'readme_complete': True,
#  'lifecycle_map': True,
#  'summary_doc': True,
#  'framework_guide_table': True}

# %% [markdown]
# ## Reflection
# The hardest stage was modeling because a richer factor set did not improve out-of-sample performance. The most reusable parts are the modular feature, model, outlier, and CLI utilities. A teammate can pick up the repo through the README, lifecycle guide, and project summary without reading every notebook first.
